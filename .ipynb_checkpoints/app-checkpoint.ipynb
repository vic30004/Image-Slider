# %%
from itertools import cycle 
import tkinter as tk

# %%
class App(tk.Tk):
    def __init__(self,image_files,x,y,delay):
        
        tk.Tk.__init__(self)

        self.geometry('+{}+{}'.format(x, y))
        self.delay = delay

        self.pictures = cycle((tk.PhotoImage(file=image), image)
                              for image in image_files)
        self.picture_display = tk.Label(self)
        self.picture_display.pack()
    def show_slides(self):
        #cycle through the images and display them

        img_object, img_name = next(self.pictures)
        self.picture_display.config(image=img_object)

        self.title(img_name)
        self.after(self.delay, self.show_slides)
    def run(self):
        self.mainloop()

# %%
delay = 3500
    
image_files = [
'1.jpg',
'2.gif',
'3.gif',
'4.gif',
'5.gif',
'6.gif',
'7.gif'
]


x=100
y=50
app=App(image_files,x,y,delay)
app.show_slides()
app.run()
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# <ipython-input-31-d12fca3b524f> in <module>
#      15 y=50
#      16 app=App(image_files,x,y,delay)
# ---> 17 app.show_slides()
#      18 app.run()
#
# <ipython-input-27-7f5981b3e8d2> in show_slides(self)
#      14         #cycle through the images and display them
#      15
# ---> 16         img_object, img_name = next(self.pictures)
#      17         self.picture_display.config(image=img_object)
#      18
#
# <ipython-input-27-7f5981b3e8d2> in <genexpr>(.0)
#       8
#       9         self.pictures = cycle((tk.PhotoImage(file=image), image)
# ---> 10                               for image in image_files)
#      11         self.picture_display = tk.Label(self)
#      12         self.picture_display.pack()
#
# D:\anaconda\lib\tkinter\__init__.py in __init__(self, name, cnf, master, **kw)
#    3543         Valid resource names: data, format, file, gamma, height, palette,
#    3544         width."""
# -> 3545         Image.__init__(self, 'photo', name, cnf, master, **kw)
#    3546     def blank(self):
#    3547         """Display a transparent image."""
#
# D:\anaconda\lib\tkinter\__init__.py in __init__(self, imgtype, name, cnf, master, **kw)
#    3499                 v = self._register(v)
#    3500             options = options + ('-'+k, v)
# -> 3501         self.tk.call(('image', 'create', imgtype, name,) + options)
#    3502         self.name = name
#    3503     def __str__(self): return self.name
#
# TclError: couldn't open "1.jpg": no such file or directory
